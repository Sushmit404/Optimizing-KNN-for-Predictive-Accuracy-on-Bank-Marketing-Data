# %% [markdown]
# ##KNN

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import requests
import json
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import statistics
#https://archive.ics.uci.edu/ml/datasets/bank+marketing

# %% [markdown]
# Obtaining Data

# %%
url = 'https://api.apispreadsheets.com/api/dataset/bank-marketing/'

# %%
response = requests.get(url)
dataset = json.loads(response.text)

# %%
dataset["data"][0].keys()
# Out:
# dict_keys(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y'])

# %%
df = pd.json_normalize(dataset["data"]) #json to table
# df = df.rename(columns={"balance": "y"}) For other datasets w/o y as final col name

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct      79.0         1   -1.0         0  unknown  no
# 1     cellular   11   may     220.0         1  339.0         4  failure  no
# 2     cellular   16   apr     185.0         1  330.0         1  failure  no
# 3      unknown    3   jun     199.0         4   -1.0         0  unknown  no
# 4      unknown    5   may     226.0         1   -1.0         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul     329.0         5   -1.0         0  unknown  no
# 4517   unknown    9   may     153.0         1   -1.0         0  unknown  no
# 4518  cellular   19   aug     151.0        11   -1.0         0  unknown  no
# 4519  cellular    6   feb     129.0         4  211.0         3    other  no
# 4520  cellular    3   apr     345.0         2  249.0         7    other  no
#
# [4521 rows x 17 columns]

# %% [markdown]
# Features and labels

# %%
feature_df = df.drop(columns=["y"])
y = df['y']
y
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 4516    no
# 4517    no
# 4518    no
# 4519    no
# 4520    no
# Name: y, Length: 4521, dtype: object

# %%
X = pd.get_dummies(feature_df)
X
# Out:
#       age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 0      30     1787   19      79.0         1   -1.0         0       False
# 1      33     4789   11     220.0         1  339.0         4       False
# 2      35     1350   16     185.0         1  330.0         1       False
# 3      30     1476    3     199.0         4   -1.0         0       False
# 4      59        0    5     226.0         1   -1.0         0       False
# ...   ...      ...  ...       ...       ...    ...       ...         ...
# 4516   33     -333   30     329.0         5   -1.0         0       False
# 4517   57    -3313    9     153.0         1   -1.0         0       False
# 4518   57      295   19     151.0        11   -1.0         0       False
# 4519   28     1137    6     129.0         4  211.0         3       False
# 4520   44     1136    3     345.0         2  249.0         7       False
#
#       job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  month_may  \
# 0               False             False  ...      False      False      False
# 1               False             False  ...      False      False       True
# 2               False             False  ...      False      False      False
# 3               False             False  ...       True      False      False
# 4                True             False  ...      False      False       True
# ...               ...               ...  ...        ...        ...        ...
# 4516            False             False  ...      False      False      False
# 4517            False             False  ...      False      False       True
# 4518            False             False  ...      False      False      False
# 4519             True             False  ...      False      False      False
# 4520            False              True  ...      False      False      False
#
#       month_nov  month_oct  month_sep  poutcome_failure  poutcome_other  \
# 0         False       True      False             False           False
# 1         False      False      False              True           False
# 2         False      False      False              True           False
# 3         False      False      False             False           False
# 4         False      False      False             False           False
# ...         ...        ...        ...               ...             ...
# 4516      False      False      False             False           False
# 4517      False      False      False             False           False
# 4518      False      False      False             False           False
# 4519      False      False      False             False            True
# 4520      False      False      False             False            True
#
#       poutcome_success  poutcome_unknown
# 0                False              True
# 1                False             False
# 2                False             False
# 3                False              True
# 4                False              True
# ...                ...               ...
# 4516             False              True
# 4517             False              True
# 4518             False              True
# 4519             False             False
# 4520             False             False
#
# [4521 rows x 51 columns]

# %% [markdown]
# 80-20 Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# Model
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
for nn_neighbors in range(30):
  if nn_neighbors == 0:
    continue
  knn = KNeighborsClassifier(n_neighbors=nn_neighbors)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  print("Accuracy (%) for kNN with ", nn_neighbors, " nearest neighbors is: ", round(accuracy * 100,2))
# Out:
# Accuracy (%) for kNN with  1  nearest neighbors is:  84.31
# Accuracy (%) for kNN with  2  nearest neighbors is:  87.4
# Accuracy (%) for kNN with  3  nearest neighbors is:  85.75
# Accuracy (%) for kNN with  4  nearest neighbors is:  88.18
# Accuracy (%) for kNN with  5  nearest neighbors is:  87.96
# Accuracy (%) for kNN with  6  nearest neighbors is:  88.18
# Accuracy (%) for kNN with  7  nearest neighbors is:  88.07
# Accuracy (%) for kNN with  8  nearest neighbors is:  88.84
# Accuracy (%) for kNN with  9  nearest neighbors is:  88.29
# Accuracy (%) for kNN with  10  nearest neighbors is:  88.84
# Accuracy (%) for kNN with  11  nearest neighbors is:  89.17
# Accuracy (%) for kNN with  12  nearest neighbors is:  88.95
# Accuracy (%) for kNN with  13  nearest neighbors is:  89.17
# Accuracy (%) for kNN with  14  nearest neighbors is:  88.73
# Accuracy (%) for kNN with  15  nearest neighbors is:  88.62
# Accuracy (%) for kNN with  16  nearest neighbors is:  88.84
# Accuracy (%) for kNN with  17  nearest neighbors is:  88.84
# Accuracy (%) for kNN with  18  nearest neighbors is:  88.73
# Accuracy (%) for kNN with  19  nearest neighbors is:  88.84
# Accuracy (%) for kNN with  20  nearest neighbors is:  88.73
# Accuracy (%) for kNN with  21  nearest neighbors is:  88.62
# Accuracy (%) for kNN with  22  nearest neighbors is:  88.62
# Accuracy (%) for kNN with  23  nearest neighbors is:  88.62
# Accuracy (%) for kNN with  24  nearest neighbors is:  88.51
# Accuracy (%) for kNN with  25  nearest neighbors is:  88.62
# Accuracy (%) for kNN with  26  nearest neighbors is:  88.73
# Accuracy (%) for kNN with  27  nearest neighbors is:  88.51
# Accuracy (%) for kNN with  28  nearest neighbors is:  88.51
# Accuracy (%) for kNN with  29  nearest neighbors is:  88.51

# %% [markdown]
# Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

for nn_neighbors in range(30):
  if nn_neighbors == 0:
    continue
  knn = KNeighborsClassifier(n_neighbors=nn_neighbors)
  accuracy = cross_val_score(knn, X, y, cv=5)

  print("Accuracy (%) for kNN with ", nn_neighbors, " nearest neighbors is: ",round(statistics.mean(accuracy)*100, 2))
# Out:
# Accuracy (%) for kNN with  1  nearest neighbors is:  85.09
# Accuracy (%) for kNN with  2  nearest neighbors is:  87.97
# Accuracy (%) for kNN with  3  nearest neighbors is:  86.68
# Accuracy (%) for kNN with  4  nearest neighbors is:  87.81
# Accuracy (%) for kNN with  5  nearest neighbors is:  87.3
# Accuracy (%) for kNN with  6  nearest neighbors is:  87.59
# Accuracy (%) for kNN with  7  nearest neighbors is:  87.28
# Accuracy (%) for kNN with  8  nearest neighbors is:  87.86
# Accuracy (%) for kNN with  9  nearest neighbors is:  87.79
# Accuracy (%) for kNN with  10  nearest neighbors is:  88.21
# Accuracy (%) for kNN with  11  nearest neighbors is:  88.1
# Accuracy (%) for kNN with  12  nearest neighbors is:  88.3
# Accuracy (%) for kNN with  13  nearest neighbors is:  88.1
# Accuracy (%) for kNN with  14  nearest neighbors is:  88.48
# Accuracy (%) for kNN with  15  nearest neighbors is:  88.43
# Accuracy (%) for kNN with  16  nearest neighbors is:  88.54
# Accuracy (%) for kNN with  17  nearest neighbors is:  88.5
# Accuracy (%) for kNN with  18  nearest neighbors is:  88.65
# Accuracy (%) for kNN with  19  nearest neighbors is:  88.56
# Accuracy (%) for kNN with  20  nearest neighbors is:  88.61
# Accuracy (%) for kNN with  21  nearest neighbors is:  88.72
# Accuracy (%) for kNN with  22  nearest neighbors is:  88.76
# Accuracy (%) for kNN with  23  nearest neighbors is:  88.74
# Accuracy (%) for kNN with  24  nearest neighbors is:  88.7
# Accuracy (%) for kNN with  25  nearest neighbors is:  88.65
# Accuracy (%) for kNN with  26  nearest neighbors is:  88.63
# Accuracy (%) for kNN with  27  nearest neighbors is:  88.68
# Accuracy (%) for kNN with  28  nearest neighbors is:  88.7
# Accuracy (%) for kNN with  29  nearest neighbors is:  88.61

# %% [markdown]
# Normalizing a feature

# %%
# Scale the training data using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled
# Out:
# array([[-0.86564103, -0.41832772,  1.0998847 , ..., -0.21304657,
#         -0.17037239,  0.46813499],
#        [-0.11376402, -0.41344086, -0.94816038, ..., -0.21304657,
#         -0.17037239, -2.13613598],
#        [-0.30173327, -0.34535063, -1.06863362, ..., -0.21304657,
#         -0.17037239,  0.46813499],
#        ...,
#        [-0.58368715,  0.45413945,  0.4975185 , ..., -0.21304657,
#         -0.17037239,  0.46813499],
#        [ 0.35615911, -0.39617396,  0.25657202, ..., -0.21304657,
#         -0.17037239,  0.46813499],
#        [ 1.29600537,  0.48443798, -0.1048477 , ..., -0.21304657,
#         -0.17037239,  0.46813499]])

# %%
# Fit a knn model on the scaled data
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Scale the test data
X_test_scaled = scaler.transform(X_test)
print("accuracy with scaling: ", knn.score(X_test_scaled, y_test)*100)
# Out:
# accuracy with scaling:  88.06629834254144

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
pipe = Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9027624309392265
